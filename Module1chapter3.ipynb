# %% [markdown]
# Justin Hogue
# Chapter #3 "Things to do"
# The purpose of this notebook is to demonstate my understanding of the chapter. Using Python, I will answer 3.1 thru 3.6 calculating seconds per hour and seconds per day.

# %% [markdown]
# #3.1 60 seconds multiplied by 60 minutes equals 3600 seconds in an hour

# %%
60 * 60
# Out:
# 3600

# %% [markdown]
# #3.2 assigning this value to a variable

# %%
seconds_per_hour = 60 * 60

# %% [markdown]
# #3.3 calculating seconds in a day

# %%
seconds_per_hour * 24
# Out:
# 86400

# %% [markdown]
# #3.4 assigning this value to a variable

# %%
seconds_per_day = seconds_per_hour * 24

# %% [markdown]
# #3.5 floating point division

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# #3.6 Integer division

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Yes, both integer and floating point division produce the same value.
